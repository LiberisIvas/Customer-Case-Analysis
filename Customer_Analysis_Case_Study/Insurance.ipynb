# %%
# - Aggregate data into one Data Frame using Pandas.
# - Standardizing header names
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - Removing duplicates
# - Replacing null values – Replace missing values with means of the column (for numerical columns)

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Data/file1.csv')
df2 = pd.read_csv('Data/file2.csv')
df3 = pd.read_csv('Data/file3.csv')

# %%
def column_name_capitalize (df):
    df.columns = df.columns.str.upper()
    return df

# %%
column_name_capitalize(df1)
column_name_capitalize(df2)
column_name_capitalize(df3)
# Out:
#      CUSTOMER       STATE  CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          POLICY TYPE  TOTAL CLAIM AMOUNT  VEHICLE CLASS
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
df1
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      NUMBER OF OPEN COMPLAINTS     POLICY TYPE  VEHICLE CLASS  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       TOTAL CLAIM AMOUNT
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
df2
# Out:
#     CUSTOMER          ST GENDER EDUCATION CUSTOMER LIFETIME VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  TOTAL CLAIM AMOUNT  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         POLICY TYPE  VEHICLE CLASS
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
df3
# Out:
#      CUSTOMER       STATE  CUSTOMER LIFETIME VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          POLICY TYPE  TOTAL CLAIM AMOUNT  VEHICLE CLASS
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
def rearrange_columns(df, oldn, newn):
    return df.rename(columns = {oldn:newn}, inplace=True)

# %%
rearrange_columns(df1,'ST', 'STATE')

# %%
rearrange_columns(df2,'ST', 'STATE')

# %%
rearrange_columns(df3,'ST', 'STATE')

# %%
def rearrange_col(df, list_of_new_col_names):
    df = df[list_of_new_col_names]
    return df

# %%
new_column_names = list(df1.columns)

# %%
df2 = rearrange_col(df2, new_column_names)

# %%
df3 = rearrange_col(df3, new_column_names)

# %%
df2
# Out:
#     CUSTOMER       STATE GENDER EDUCATION CUSTOMER LIFETIME VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#      VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0    Four-Door Car          633.600000
# 1              SUV          547.200000
# 2     Two-Door Car          537.600000
# 3       Luxury Car         1027.200000
# 4     Two-Door Car          451.200000
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [996 rows x 11 columns]

# %%
df2.head()
# Out:
#   CUSTOMER       STATE GENDER EDUCATION CUSTOMER LIFETIME VALUE  INCOME  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# 2   Two-Door Car               537.6
# 3     Luxury Car              1027.2
# 4   Two-Door Car               451.2

# %%
Mu = pd.concat([df1, df2, df3])

# %%
Mu
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                   23406  71941.0                  73.0
# 7066                 3096.51  21604.0                  79.0
# 7067                 8163.89      0.0                  85.0
# 7068                 7524.44  21941.0                  96.0
# 7069                 2611.84      0.0                  77.0
#
#      NUMBER OF OPEN COMPLAINTS     POLICY TYPE  VEHICLE CLASS  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       TOTAL CLAIM AMOUNT
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [12074 rows x 11 columns]

# %%
def drop_col(df, column_name):
    Mu.drop(columns=[column_name], inplace=True)
    return df

# %%
drop_col(Mu, 'CUSTOMER')
# Out:
#            STATE GENDER             EDUCATION CUSTOMER LIFETIME VALUE  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                   23406
# 7066  California      F               College                 3096.51
# 7067  California      M              Bachelor                 8163.89
# 7068  California      M               College                 7524.44
# 7069  California      M               College                 2611.84
#
#        INCOME  MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 7065  Four-Door Car          198.234764
# 7066  Four-Door Car          379.200000
# 7067  Four-Door Car          790.784983
# 7068  Four-Door Car          691.200000
# 7069   Two-Door Car          369.600000
#
# [12074 rows x 10 columns]

# %%
Mu['CUSTOMER LIFETIME VALUE'] = Mu['CUSTOMER LIFETIME VALUE'].replace({'%':''}, regex = True)

# %%
Mu['CUSTOMER LIFETIME VALUE'] = pd.to_numeric(Mu['CUSTOMER LIFETIME VALUE'], errors = 'coerce')
Mu['CUSTOMER LIFETIME VALUE'] = Mu

# %%
Mu['CUSTOMER LIFETIME VALUE'].isna().sum()
# Out:
# 2937

# %%
Mu['NUMBER OF OPEN COMPLAINTS'].str.contains('1/1/00').sum()
# Out:
# 247

# %%
Mu.pivot_table(columns=['CUSTOMER LIFETIME VALUE'], aggfunc='size')
# Out:
# CUSTOMER LIFETIME VALUE
# AZ              74
# Arizona       1630
# Cali           120
# California    3032
# Nevada         882
# Oregon        2601
# WA              30
# Washington     768
# dtype: int64

# %%
Mu['GENDER'].str.upper()
Mu['GENDER'].str.contains('NaN').sum()
# Out:
# 0

# %%
Mu['GENDER'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
# def replace_value(df_column,old_phrase, new_phrase ):
#     df_column.replace(old_phrase, new_phrase, regex = True)
#     return df_column

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/0/00', 0 , regex=True)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'].unique()
# Out:
# array([0, '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 2, 3, 1,
#        5, 4], dtype=object)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/2/00', 2 , regex=True)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/3/00', 3 , regex=True)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/5/00', 5 , regex=True)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/4/00', 4 , regex=True)

# %%
Mu['NUMBER OF OPEN COMPLAINTS'] = Mu['NUMBER OF OPEN COMPLAINTS'].replace('1/1/00', 1 , regex=True)

# %%
# Mu['GENDER'] = Mu['GENDER'].str.upper()

# %%
Mu['GENDER'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
# Mu['GENDER']=Mu['GENDER'].fillna(value="N/A")

# %%
# def change_str_gender(df_column):
#     for i in Mu['GENDER']:
#         if i.startswith("N"):
#             continue
#         elif i.startswith('F'):
#             i='F'
#         else:
#             i='M'
#         return: df_column

# %%
# def change_str_gender(df_column):
#     for i in df_column:
#         if i.startswith("N"):
#             return 'N/A'
#         elif i.startswith('F'):
#             return 'F'
#         else:
#             return 'M'

# %%
Mu['GENDER'] = Mu['GENDER'].replace({'Femal':'F', 'female': 'F', 'Male': 'M'})

# %%
Mu['GENDER'].value_counts()
# Out:
# F    4607
# M    4408
# Name: GENDER, dtype: int64

# %%
# def change_str_country(df_column):
#     for i in df_column:
#             if i.startswith('A'):
#                 return 'Arizona'
#             elif i.startswith('W'):
#                 return 'Washington'
#             elif i.startswith('C'):
#                 return 'California'
#             elif i == "N":
#                 return 'Nevada'
#             elif i.startswith('O'):
#                 return 'Oregon'
#             else:
#                 return i

# %%
Mu['GENDER'].value_counts()
# Out:
# F    4607
# M    4408
# Name: GENDER, dtype: int64

# %%
#Mu['STATE'] =list(map(change_str_country, Mu['STATE'] ))

# %%
Mu.head()
# Out:
#         STATE GENDER             EDUCATION CUSTOMER LIFETIME VALUE   INCOME  \
# 0  Washington    NaN                Master              Washington      0.0
# 1     Arizona      F              Bachelor                 Arizona      0.0
# 2      Nevada      F              Bachelor                  Nevada  48767.0
# 3  California      M              Bachelor              California      0.0
# 4  Washington      M  High School or Below              Washington  36357.0
#
#    MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0                1000.0                        0.0   Personal Auto
# 1                  94.0                        0.0   Personal Auto
# 2                 108.0                        0.0   Personal Auto
# 3                 106.0                        0.0  Corporate Auto
# 4                  68.0                        0.0   Personal Auto
#
#    VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %%
Mu['STATE'].value_counts()
# Out:
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: STATE, dtype: int64

# %%
Mu['STATE'] = Mu['STATE'].replace({'Cali':'California', 'AZ': 'Arizona', 'WA': 'Washington'})

# %%
Mu['STATE'].value_counts()
# Out:
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: STATE, dtype: int64

# %%
Mu['STATE'].value_counts(dropna=False)
# Out:
# California    3152
# NaN           2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: STATE, dtype: int64

# %%
Mu['EDUCATION'] = Mu['EDUCATION'].replace({'Bachelor':'Bachelors'})

# %%
Mu['TOTAL CLAIM AMOUNT'] = Mu['TOTAL CLAIM AMOUNT'].round(2)

# %%
Mu
# Out:
#            STATE GENDER             EDUCATION CUSTOMER LIFETIME VALUE  \
# 0     Washington    NaN                Master              Washington
# 1        Arizona      F             Bachelors                 Arizona
# 2         Nevada      F             Bachelors                  Nevada
# 3     California      M             Bachelors              California
# 4     Washington      M  High School or Below              Washington
# ...          ...    ...                   ...                     ...
# 7065  California      M             Bachelors              California
# 7066  California      F               College              California
# 7067  California      M             Bachelors              California
# 7068  California      M               College              California
# 7069  California      M               College              California
#
#        INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7065  71941.0                  73.0                        0.0
# 7066  21604.0                  79.0                        0.0
# 7067      0.0                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069      0.0                  77.0                        0.0
#
#          POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0      Personal Auto  Four-Door Car                2.70
# 1      Personal Auto  Four-Door Car             1131.46
# 2      Personal Auto   Two-Door Car              566.47
# 3     Corporate Auto            SUV              529.88
# 4      Personal Auto  Four-Door Car               17.27
# ...              ...            ...                 ...
# 7065   Personal Auto  Four-Door Car              198.23
# 7066  Corporate Auto  Four-Door Car              379.20
# 7067  Corporate Auto  Four-Door Car              790.78
# 7068   Personal Auto  Four-Door Car              691.20
# 7069  Corporate Auto   Two-Door Car              369.60
#
# [12074 rows x 10 columns]

# %%
Mu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
# STATE                        9137 non-null object
# GENDER                       9015 non-null object
# EDUCATION                    9137 non-null object
# CUSTOMER LIFETIME VALUE      9137 non-null object
# INCOME                       9137 non-null float64
# MONTHLY PREMIUM AUTO         9137 non-null float64
# NUMBER OF OPEN COMPLAINTS    9137 non-null float64
# POLICY TYPE                  9137 non-null object
# VEHICLE CLASS                9137 non-null object
# TOTAL CLAIM AMOUNT           9137 non-null float64
# dtypes: float64(4), object(6)
# memory usage: 1.0+ MB

# %%
Mu = Mu.drop_duplicates()

# %%
Mu['GENDER'].isnull().sum()
# Out:
# 3059

# %%
# Out:
#            STATE GENDER             EDUCATION CUSTOMER LIFETIME VALUE  \
# 0     Washington    NaN                Master              Washington
# 1        Arizona      F             Bachelors                 Arizona
# 2         Nevada      F             Bachelors                  Nevada
# 3     California      M             Bachelors              California
# 4     Washington      M  High School or Below              Washington
# ...          ...    ...                   ...                     ...
# 7064  California      F               College              California
# 7065  California      M             Bachelors              California
# 7067  California      M             Bachelors              California
# 7068  California      M               College              California
# 7069  California      M               College              California
#
#        INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7064  47761.0                 104.0                        0.0
# 7065  71941.0                  73.0                        0.0
# 7067      0.0                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069      0.0                  77.0                        0.0
#
#          POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0      Personal Auto  Four-Door Car                2.70
# 1      Personal Auto  Four-Door Car             1131.46
# 2      Personal Auto   Two-Door Car              566.47
# 3     Corporate Auto            SUV              529.88
# 4      Personal Auto  Four-Door Car               17.27
# ...              ...            ...                 ...
# 7064   Personal Auto  Four-Door Car              541.28
# 7065   Personal Auto  Four-Door Car              198.23
# 7067  Corporate Auto  Four-Door Car              790.78
# 7068   Personal Auto  Four-Door Car              691.20
# 7069  Corporate Auto   Two-Door Car              369.60
#
# [8667 rows x 10 columns]

# %%
Mu['GENDER'].value_counts(dropna=False)
# Out:
# F      4381
# M      4163
# NaN     123
# Name: GENDER, dtype: int64

# %%
Mu['INCOME'].fillna(value=pd.mean(Mu['INCOME']), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-d49c47da9233> in <module>
# ----> 1 Mu['INCOME']= Mu['INCOME'].fillna(value=mean_value, inplace=True)
#
# NameError: name 'mean_value' is not defined

# %%
Mu['INCOME'].fillna(np.mean(Mu['INCOME']), inplace=True)
# Out:
# C:\Users\Seinf\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
Mu['MONTHLY PREMIUM AUTO'].fillna(np.mean(Mu['MONTHLY PREMIUM AUTO']), inplace=True)

# %%
Mu['MONTHLY PREMIUM AUTO']=round(Mu['MONTHLY PREMIUM AUTO']. inplace=True))

# %%
Mu['TOTAL CLAIM AMOUNT'].fillna(np.mean(Mu['TOTAL CLAIM AMOUNT']), inplace=True)

# %%
Mu['TOTAL CLAIM AMOUNT'].value_counts()
# Out:
# 316.80    106
# 292.80    102
# 312.00    101
# 331.20     98
# 321.60     94
#          ...
# 99.09       1
# 357.64      1
# 810.07      1
# 454.36      1
# 933.33      1
# Name: TOTAL CLAIM AMOUNT, Length: 4913, dtype: int64

# %%
Mu=Mu.applymap(lambda s: s.lower() if type(s)==str else s)

# %%
Mu
# Out:
#            STATE GENDER             EDUCATION CUSTOMER LIFETIME VALUE  \
# 0     washington    NaN                master              washington
# 1        arizona      f             bachelors                 arizona
# 2         nevada      f             bachelors                  nevada
# 3     california      m             bachelors              california
# 4     washington      m  high school or below              washington
# ...          ...    ...                   ...                     ...
# 7064  california      f               college              california
# 7065  california      m             bachelors              california
# 7067  california      m             bachelors              california
# 7068  california      m               college              california
# 7069  california      m               college              california
#
#        INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 7064  47761.0                 104.0                        0.0
# 7065  71941.0                  73.0                        0.0
# 7067      0.0                  85.0                        3.0
# 7068  21941.0                  96.0                        0.0
# 7069      0.0                  77.0                        0.0
#
#          POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0      personal auto  four-door car                2.70
# 1      personal auto  four-door car             1131.46
# 2      personal auto   two-door car              566.47
# 3     corporate auto            suv              529.88
# 4      personal auto  four-door car               17.27
# ...              ...            ...                 ...
# 7064   personal auto  four-door car              541.28
# 7065   personal auto  four-door car              198.23
# 7067  corporate auto  four-door car              790.78
# 7068   personal auto  four-door car              691.20
# 7069  corporate auto   two-door car              369.60
#
# [8667 rows x 10 columns]

# %%
region_dict = {'california': 'west region', 'oregon' : 'north west', 'washington': 'east', 'arizona' : 'central', 'nevada': 'central'}
Mu['REGION'] = Mu['STATE'].map(region_dict)
Mu
# Out:
#            REGION       REGION       STATE GENDER             EDUCATION  \
# 0            east         east  washington    NaN                master
# 1         central      central     arizona      f             bachelors
# 2         central      central      nevada      f             bachelors
# 3     west region  west region  california      m             bachelors
# 4            east         east  washington      m  high school or below
# ...           ...          ...         ...    ...                   ...
# 7064  west region  west region  california      f               college
# 7065  west region  west region  california      m             bachelors
# 7067  west region  west region  california      m             bachelors
# 7068  west region  west region  california      m               college
# 7069  west region  west region  california      m               college
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                 washington      0.0                1000.0
# 1                    arizona      0.0                  94.0
# 2                     nevada  48767.0                 108.0
# 3                 california      0.0                 106.0
# 4                 washington  36357.0                  68.0
# ...                      ...      ...                   ...
# 7064              california  47761.0                 104.0
# 7065              california  71941.0                  73.0
# 7067              california      0.0                  85.0
# 7068              california  21941.0                  96.0
# 7069              california      0.0                  77.0
#
#       NUMBER OF OPEN COMPLAINTS     POLICY TYPE  VEHICLE CLASS  \
# 0                           0.0   personal auto  four-door car
# 1                           0.0   personal auto  four-door car
# 2                           0.0   personal auto   two-door car
# 3                           0.0  corporate auto            suv
# 4                           0.0   personal auto  four-door car
# ...                         ...             ...            ...
# 7064                        0.0   personal auto  four-door car
# 7065                        0.0   personal auto  four-door car
# 7067                        3.0  corporate auto  four-door car
# 7068                        0.0   personal auto  four-door car
# 7069                        0.0  corporate auto   two-door car
#
#       TOTAL CLAIM AMOUNT
# 0                   2.70
# 1                1131.46
# 2                 566.47
# 3                 529.88
# 4                  17.27
# ...                  ...
# 7064              541.28
# 7065              198.23
# 7067              790.78
# 7068              691.20
# 7069              369.60
#
# [8667 rows x 12 columns]

# %%
Mu = Mu[['REGION', 'STATE', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE', 'INCOME', 'MONTHLY PREMIUM AUTO','NUMBER OF OPEN COMPLAINTS', 'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT']]

# %%
Mu.columns
# Out:
# Index(['REGION', 'REGION', 'STATE', 'GENDER', 'EDUCATION',
#        'CUSTOMER LIFETIME VALUE', 'INCOME', 'MONTHLY PREMIUM AUTO',
#        'NUMBER OF OPEN COMPLAINTS', 'POLICY TYPE', 'VEHICLE CLASS',
#        'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
Mu = Mu[['REGION', 'STATE', 'GENDER', 'EDUCATION',
       'CUSTOMER LIFETIME VALUE', 'INCOME', 'MONTHLY PREMIUM AUTO',
       'NUMBER OF OPEN COMPLAINTS', 'POLICY TYPE', 'VEHICLE CLASS',
       'TOTAL CLAIM AMOUNT']]

# %%
Mu
# Out:
#            REGION       REGION       STATE GENDER             EDUCATION  \
# 0            east         east  washington    NaN                master
# 1         central      central     arizona      f             bachelors
# 2         central      central      nevada      f             bachelors
# 3     west region  west region  california      m             bachelors
# 4            east         east  washington      m  high school or below
# ...           ...          ...         ...    ...                   ...
# 7064  west region  west region  california      f               college
# 7065  west region  west region  california      m             bachelors
# 7067  west region  west region  california      m             bachelors
# 7068  west region  west region  california      m               college
# 7069  west region  west region  california      m               college
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                 washington      0.0                1000.0
# 1                    arizona      0.0                  94.0
# 2                     nevada  48767.0                 108.0
# 3                 california      0.0                 106.0
# 4                 washington  36357.0                  68.0
# ...                      ...      ...                   ...
# 7064              california  47761.0                 104.0
# 7065              california  71941.0                  73.0
# 7067              california      0.0                  85.0
# 7068              california  21941.0                  96.0
# 7069              california      0.0                  77.0
#
#       NUMBER OF OPEN COMPLAINTS     POLICY TYPE  VEHICLE CLASS  \
# 0                           0.0   personal auto  four-door car
# 1                           0.0   personal auto  four-door car
# 2                           0.0   personal auto   two-door car
# 3                           0.0  corporate auto            suv
# 4                           0.0   personal auto  four-door car
# ...                         ...             ...            ...
# 7064                        0.0   personal auto  four-door car
# 7065                        0.0   personal auto  four-door car
# 7067                        3.0  corporate auto  four-door car
# 7068                        0.0   personal auto  four-door car
# 7069                        0.0  corporate auto   two-door car
#
#       TOTAL CLAIM AMOUNT
# 0                   2.70
# 1                1131.46
# 2                 566.47
# 3                 529.88
# 4                  17.27
# ...                  ...
# 7064              541.28
# 7065              198.23
# 7067              790.78
# 7068              691.20
# 7069              369.60
#
# [8667 rows x 12 columns]
